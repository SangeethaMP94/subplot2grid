# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(20,10))
a1 = plt.subplot2grid((5,10),(0,0),colspan = 4)
a2 = plt.subplot2grid((5,10),(1,0),rowspan = 3, colspan = 2)
a3 = plt.subplot2grid((5,10),(4,0))
a4 = plt.subplot2grid((5,10),(0,4), colspan = 3)
a5 = plt.subplot2grid((5,10),(1,2), colspan = 5)
a6 = plt.subplot2grid((5,10),(2,2),rowspan = 2)
a7 = plt.subplot2grid((5,10),(4,1),colspan = 3)
a8 = plt.subplot2grid((5,10),(2,3),rowspan = 2, colspan = 4)
a8.bar(x,y)
a9 = plt.subplot2grid((5,10),(4,4))
a10 = plt.subplot2grid((5,10),(4,5))
a11 = plt.subplot2grid((5,10),(4,6))
a12 = plt.subplot2grid((5,10),(0,7),rowspan = 5)
a13 = plt.subplot2grid((5,10),(0,8),rowspan = 5, colspan = 2)
plt.tight_layout()
plt.show()
